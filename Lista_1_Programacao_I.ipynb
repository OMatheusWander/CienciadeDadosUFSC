# %% [markdown]
# <a href="https://colab.research.google.com/github/OMatheusWander/CienciadeDadosUFSC/blob/Programa%C3%A7%C3%A3o-I/Lista_1_Programacao_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LISTA 1 DE PROGRAMAÇÃO I

# %% [markdown]
# Exercício 1

# %%
#ALGORITMO 1

#VAR
# palavra: string
#INICIO
palavra = input("Digite uma palavra:")
#FIM
palavra

# %% [markdown]
# Exercício 2

# %%
#ALGORITMO 2
#VAR
# palavra1: string
# palavra2: string
#INICIO
palavra1 = input("Digite a primeira palavra:")
palavra2 = input("Digite a segunda palavra:")
#FIM
print(palavra1, palavra2)

# %%
#ALGORITMO 3

#VAR
# Nome: string
# Cidade: string
#INICIO
Nome = input("Digite um nome:")
Cidade = input("Digite uma cidade:")
#FIM
print(Nome,"mora em", Cidade)

# %% [markdown]
# Exercício 4

# %%
#ALGORITMO 4

#VAR
#num_inteiro: int

#INICIO
num_inteiro = input("Digite um número inteiro:")
#FIM
num_inteiro

# %% [markdown]
# Exercício 5

# %%
#ALGORITMO 5

#VAR
#n_int_1: int
#n_int_2: int

#INICIO
n_int_1 = input("Digite o primeiro número inteiro:") #Leia
n_int_2 = input("Digite o segundo número inteiro:")

#FIM
int(n_int_1) + int(n_int_2)
#Escreva

# %% [markdown]
# Exercício 6

# %%
#ALGORITMO 6

#VAR
#n_int_1: int
#n_int_2: int

#INICIO
n_int_1 = input("Digite o primeiro número inteiro:") #Leia
n_int_2 = input("Digite o segundo número inteiro:")

#FIM
int(n_int_1) - int(n_int_2)
#Escreva

# %% [markdown]
# Exercício 7

# %%
#ALGORITMO 7

#VAR
#n_1: float
#n_2: float

#INICIO
n_1 = input("Digite o primeiro número real:") #Leia
n_2 = input("Digite o segundo número real:")

#FIM
float(n_1) * float(n_2)
#Escreva

# %% [markdown]
# Exercício 8

# %%
#ALGORITMO 8

#VAR
#n_1: int
#n_2: int

#INICIO
n_1 = input("Digite o primeiro número real:") #Leia
n_2 = input("Digite o segundo número real:")

#FIM
float(n_1) / float(n_2)
#Escreva

# %% [markdown]
# Exercício 9

# %%
#ALGORITMO 9

#VAR
#n_int_1: int

#INICIO
n_int_1 = input("Digite um número inteiro:") #Leia

#FIM
print("Dobro:", int(n_int_1) *2)
print("Triplo:", int(n_int_1) *3)
print("Quádruplo:", int(n_int_1) *4)
#Escreva

# %% [markdown]
# Exercício 10

# %%
#ALGORITMO 10

#VAR
#n_float_1: float

#INICIO
n_float_1 = input("Digite um número real:") #Leia

#FIM
print("Metade:", int(n_float_1) /2)
print("Quinta parte:", int(n_float_1) / 5)
#Escreva

# %% [markdown]
# Exercício 11

# %%
#ALGORITMO 11

#VAR
#n_int_1: int
#n_int_2: int
#n_int_3: int

#INICIO
n_int_1 = input("Digite o prmeiro número real:") #Leia
n_int_2 = input("Digite o segundo número real:") #Leia
n_int_3 = input("Digite o terceiro número real:") #Leia

#FIM
print("A soma total é:", int(n_int_1) + int(n_int_2) + int(n_int_3))

#Escreva

# %% [markdown]
# Exercício 12

# %%
#ALGORITMO 12

#VAR
#n_int_1: float
#n_int_2: float
#n_int_3: float

#INICIO
n_int_1 = input("Digite o prmeiro número real:") #Leia
n_int_2 = input("Digite o segundo número real:") #Leia
n_int_3 = input("Digite o terceiro número real:") #Leia

#FIM
print("A média aritmética:", (float(n_int_1) + float(n_int_2) + float(n_int_3))/3)

#Escreva

# %% [markdown]
# Exercício 13

# %%
#ALGORITMO 13

#VAR
#cidade: string
#numero: float


#INICIO
cidade = input("Digite uma palavra:") #Leia
numero = input("Digite um número:") #Leia

#FIM
print((round(float(numero))))
print(cidade)

#Escreva

# %% [markdown]
# Exercício 14

# %%
#ALGORITMO 14

#VAR
#palavra: string
#numero: string


#INICIO
palavra = input("Digite uma palavra:") #Leia
numero = input("Digite um número:") #Leia

#FIM
print((round(float(numero))))
print(palavra)
print((round(float(numero))))
print(palavra)
print((round(float(numero))))
print((round(float(numero))))
print(palavra)
print(palavra)
#Escreva

# %% [markdown]
# Exercício 15

# %%
#ALGORITMO 15

#VAR
#palavra: string
#numero_int: int
#numero_real: flot

#INICIO
palavra = input("Digite uma palavra:") #Leia
numero_int = input("Digite um número inteiro:") #Leia
numero_real = input("Digite um número real:") #Leia

#FIM
print((int(numero_int)))
print(palavra)
print(float(numero_real))
print(float(numero_real))
print(palavra)
print(palavra)
print(palavra)
print((int(numero_int)))
print((int(numero_int)))
print((int(numero_int)))
print(float(numero_real))
#Escreva

# %% [markdown]
# Exercício 16

# %%
#ALGORITMO 16

#VAR
#palavra_1, palavra_2, palavra_3, palavra_4: string

#INICIO
#LEIA
palavra_1 = input("Digite a primeira palavra:")
palavra_2 = input("Digite a segunda palavra:")
palavra_3 = input("Digite a terceira  palavra:")
palavra_4 = input("Digite a quarta palavra:")

#Escreva
print(palavra_1)
print(palavra_2,"   ",palavra_3,palavra_4)

#FIM

# %% [markdown]
# Exercício 17

# %%
#ALGORITMO 17

#VAR
#palavra_1, palavra_2, palavra_3, palavra_4: string

#INICIO
#LEIA
palavra_1 = input("Digite a primeira palavra:")
palavra_2 = input("Digite a segunda palavra:")
palavra_3 = input("Digite a terceira palavra:")
palavra_4 = input("Digite a quarta palavra:")

#Escreva
print(palavra_1,"\n",palavra_2,"\t",palavra_3,palavra_4)
#FIM

# %% [markdown]
# Exercício 17

# %%
#ALGORITMO 17

#VAR
#palavra: string
#numero_int: int
#numero_real: float

#Inicio
#LEIA
palavra = input("Digite uma palavra:")
numero_int = input("Digite um número inteiro:")
numero_real = input("Digite um número real:")

#Escreva
print("A palavra digitada foi:", palavra)
print("Quando subtraímos o número real do inteiro, obtemos:", float(numero_real) - int(numero_int))

#Fim

# %% [markdown]
# Exercício 18

# %%
#ALGORITMO 18

#VAR
#numero, numero1, numero2: float

#Inicio
#LEIA
numero = input("Digite um número:")
numero1 = input("Digite outro número:")
numero2 = input("Digite mais um número:")

#Escreva
print("A média entre os três números é:", (float(numero) + float(numero1) + float(numero2))/3)

#Fim

# %% [markdown]
# Exercício 19

# %%
#ALGORITMO 19

#VAR
#numero: int

#Inicio
#LEIA
numero = input("Digite um número:")

#Escreva
print("Sucessor:", int(numero)-1,"\n","Antecessor:",int(numero)+1)

#Fim

# %% [markdown]
# Exercício 20

# %%
#ALGORITMO 20

#VAR
# nome, sobrenome, rua, telefone: string
# num_resd, ddd: int

#INÍCIO
#LÊ
nome = input("Digite o primeiro nome:")
sobrenome = input("Digite o sobrenome:")
rua = input("Digite o nome da rua:")
num_resd = input("Digite o número da residência:")
ddd = input("Digite o código de área:")
telefone = input("Digite o número de telefone:")

#Escreva
print(f"Nome Completo: {nome}{sobrenome}\nEndereço:{rua}, número {num_resd} \nTelefone:{ddd} {telefone}")

# %% [markdown]
# Exercício 21

# %%
#ALGORITMO 21

#VARIAVEIS
#num_real: float

#INICIO
num_real = float(input("Digite um número real:"))  #LEIA
terceira_parte = float(num_real)/3

#ESCREVA
print("A terça parte inteira do número digitado é:{}".format(int(terceira_parte)))
print("A terça parte real do número digitado é:{0:.3f}".format(terceira_parte))

#FIM

# %% [markdown]
# Exercício 22

# %%
#ALGORITMO 22

#VARIAVEIS
#int_1: int
#int_2: int

#INICIO
int_1 = int(input("Digite o primeiro número real:"))  #LEIA
int_2 = int(input("Digite o segundo número real:"))  #LEIA
quociente = int(int_1 / int_2)
resto = int_1 % int_2


#ESCREVA
print(f"Dividendo:{int_1}")
print(f"Divisor:{int_2}")
print(f"Quociente:{quociente}")
print(f"Resto:{resto}")

#FIM

# %% [markdown]
# Exercício 23

# %%
#ALGORITMO 23

#VARIAVEL
#valor_a, valor_b, valor_c, valor_d: float

#INICIO
#LÊ
valor_a = float(input("a:"))
valor_b = float(input("b:"))
valor_c = float(input("c:"))
valor_d = float(input("d:"))

#PROCESSAMENTO
calculo = (2 * valor_a + 3 ** valor_b - 50 % valor_c) + 100 // valor_d

#ESCREVE
print(calculo)


#FIM

# %% [markdown]
# Exercício 24

# %%
#ALGORITMO 24

#VARIÁVEIS
#palavra: string
#int: int
#real: float

#INICIO
#LÊ
palavra = input("Digite uma palavra:")
inteiro = int(input("Digite um número inteiro:"))
real = float(input("Digite um número real:"))

#PROCESSA

#ESCREVE
print(f"Primeira sequência: {palavra}#{inteiro}#{real}#")
print("Segunda sequência:"+3* f"{inteiro}#"+palavra+ f"{inteiro}#{real}#{inteiro}")
print("Terceira sequência:"+3* f"{palavra}    "+f"{palavra}_"+ f"{inteiro}_{real}")

#FIM

# %% [markdown]
# Exercício 25

# %%
#ALGORITMO 25

#VARIAVEIS
#inteiro0, inteiro1: int

#INICIO
#LÊ
inteiro0 = int(input("Digite um número inteiro:"))
inteiro1 = int(input("Digite outro número:"))

#PROCESSAMENTO
soma = inteiro0 + inteiro1

#ESCREVA

print(f"### Resultado da Operação ###\n {inteiro0}","+",f"{inteiro1}","=",f"{soma}")

# %% [markdown]
# Exercício 26

# %%
#ALGORITMO 26

#VARIAVEIS
#nome, endereço, email, curso: string
#bolsa_atual: float
#bolsa_5%:float

nome = input("Nome completo:")
endereço = input("Endereço:")
email = input("Email:")
curso = input("Curso:")
bolsa_atual = float(input("Valor da Bolsa atual:"))

#INICIO

#PROCESSA
bolsa_5_pct = bolsa_atual * 1.05

#ESCREVE
nome
endereço
email
curso

print("R${:.2f}".format(bolsa_atual))
print("R${:.2f}".format(bolsa_5_pct))

#print(f"R${bolsa_5_pct:.2f}")

# %% [markdown]
# Exercício 27

# %%
#ALGORITMO 27

#VARIAVEIS
#temp_c: float


temp_c = float(input("Digite a temperatura em Celsius:"))

#INICIO

#PROCESSA
temp_f = ((temp_c * 9)/ 5)+32

#ESCREVE
print("Temperatura em Fahrenheit:",temp_f)

#FIM

# %% [markdown]
# Exercício 28

# %%
#ALGORITMO 28

#VARIAVEIS
#temp_f: float


temp_f = float(input("Digite a temperatura em Fahrenheit:"))

#INICIO

#PROCESSA
temp_c = ((temp_f -32) * 5)/9

#ESCREVE
print("Temperatura em Celsius:",temp_c)

#FIM

# %% [markdown]
# Exercício 29

# %%
#ALGORITMO 29

#VARIAVEIS
#base, altura: float
#altura

temp_c = float(input("Digite a temperatura em Celsius:"))

#INICIO

#PROCESSA
temp_f = ((temp_c * 9)/ 5)+32

#ESCREVE
print("Temperatura em Fahrenheit:",temp_f)

#FIM

# %% [markdown]
# Exercício 30

# %%
#ALGORITMO 30

#VARIAVEIS
#ladoquadrado: int

ladoquadrado = int(input("Digite o lado do quadrado:"))

#INICIO

#PROCESSA
area = (ladoquadrado ** 2)
perimetro = ladoquadrado * 4
#ESCREVE
print("Área:",area)
print("Perímetro:",perimetro)

#FIM
# Out:
# Digite o lado do quadrado:5
# Área: 25
# Perímetro: 20

# %% [markdown]
# Exercício 31

# %%
#ALGORITMO 31

#VARIAVEIS
#raiocirculo: int

raiocirculo = int(input("Digite o raio do círculo:"))

#INICIO

#PROCESSA
diametro = (raiocirculo * 2)

#ESCREVE
print("Diâmetro:",diametro)

#FIM
# Out:
# Digite o raio do círculo:7
# Diâmetro: 14

# %% [markdown]
# Exercício 32

# %%
#ALGORITMO 32

#VARIAVEIS
#raiocirculo: float

raiocirculo1 = float(input("Digite o raio do círculo:"))

#INICIO

#PROCESSA
pi =  3.14159
area = (pi * raiocirculo1 * raiocirculo1)

#ESCREVE
print(f"Área do círculo: {area:.5f}")

#FIM
# Out:
# Digite o raio do círculo:2
# Área do círculo: 12.56636

# %% [markdown]
# Exercício 33

# %%
#ALGORITMO 33

#VARIAVEIS
#raiocirculo: float

raiocirculo1 = float(input("Digite o raio do círculo:"))

#INICIO

#PROCESSA
pi =  3.14159
area = (pi * raiocirculo1 * raiocirculo1)

#ESCREVE
print(f"Área do círculo: {area:.5f}")

#FIM

# %% [markdown]
# Exercício 39

# %%
#ALGORITMO 39

#VARIAVEIS
#inteiro_1, inteiro_2: int

inteiro_1 = int(input("Digite o primeiro número inteiro:"))
inteiro_2 = int(input("Digite o segundo número inteiro:"))

#INICIO

#PROCESSA
quociente = int(inteiro_1 / inteiro_2)
resto = inteiro_1 % inteiro_2

#ESCREVE
print(f"Quociente: {quociente}")
print(f"Resto: {resto}")

#FIM
# Out:
# Digite o primeiro número inteiro:23
# Digite o segundo número inteiro:5
# Quociente: 4
# Resto: 3
