# %% [markdown]
# <a href="https://colab.research.google.com/github/OMatheusWander/CienciadeDadosUFSC/blob/main/LISTA_4_PROGRAMA%C3%87%C3%83O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LISTA 4 DE PROGRAMAÇÃO

# %%
#Exercício 1
x = 1
while x<101:
  print(x)
  x= x+1

# %%
# Exercício 2

x = 50
while x<101:
  print(x)
  x= x+1

# %%
#Exercício 3
x = 100
while x>=50:
  print(x)
  x= x-1

# %%
#Exercício 4
x = 100
while x>=50:
  print(x)
  x= x-2

# %%
#Exercício 5

for x in range(101):
  if x != 0:
    print(x)

# %%
#Exercício 6

for x in range(100,50,-1):
#  if x != 0 and x >= 50:
    print(x, end= ",")

# %%
#Exercício 7
for x in range(100,49,-1):
    print(x, end= ",")

# %%
#Exercício 8
for x in range(100,49,-2):
    print(x, end= " ")

# %%
#Exercício 9
inteiro = int(input("Digite um número inteiro positivo:"))


print("Abaixo estão os 20 primeiros múltiplos de 4:")

for n in range(0,20,1):
  print(multiplo, end = ", ")
  multiplo = n*inteiro
# Out:
# Digite um número inteiro positivo:4
# Abaixo estão os 20 primeiros múltiplos de 4:
# 76, 0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72,
