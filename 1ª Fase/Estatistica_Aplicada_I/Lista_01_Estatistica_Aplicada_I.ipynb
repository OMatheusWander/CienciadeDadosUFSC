# %% [markdown]
# 1) Escolha uma área de interesse (Tecnologia, Administração, Saúde, Agricultura, etc.) e proponha uma pequena pesquisa fictícia nesta área.
#
# Descreva:
# a) A definição do problema de pesquisa.
#
# b) A população de interesse.
#
# c) A técnica a ser utilizada na pesquisa.
#
# d) As variáveis a serem observadas.
#
# e) Os instrumentos de coleta de dados.

# %% [markdown]
# 1. Economia
#
# a) Análise de famílias no PBF
#
# b) Famílias no PBF
#
# c) Análise estatística. Média, Moda e estimação de variáveis.
#
# d) Salário, número de pessoas, crianças estão estudando?,se tem energia elétrica,...
#
# e) ETL em R a partir de dados do VIZDATA 3.0 do SAGICAD

# %% [markdown]
# 2) Suponha que você foi contratado para realizar uma pesquisa sobre o perfil dos usuários de um site de comércio eletrônico que vende smartphones. Para isso, será necessário elaborar um instrumento de coleta de dados que permita conhecer melhor quem são esses usuários e como eles utilizam o site. Elabore um questionário com no máximo 10 perguntas que permita investigar o perfil desses usuários.

# %% [markdown]
# Questionário de perfil de usuários
#
# 1. Onde reside?
# 2. Qual a faixa salarial?
# 3. Nível de instrução
# 4. Idade
# 5. Gênero
# 6. O que procura em um smartfone?
# 7. Grau de conhecimento em tecnologia
# 8. Qual o orçamento para comprar?
# 9. É o primeiro smartfone?
# 10. A quanto tempo está com o atual smartfone

# %% [markdown]
# 3) Considere que uma empresa deseja avaliar a satisfação dos clientes de uma de suas lojas. Durante a elaboração do questionário, foram propostas as seguintes perguntas:
# 1. “Você concorda que nossa loja tem um bom atendimento?”
# 2. “Você também acha que nossos preços são melhores do que a concorrência?”
# 3. “Por que você gosta de comprar em nossa loja?”
# 4. “Com que frequência você visita a nossa loja?”

# %% [markdown]
# a) Identifique quais perguntas podem gerar viés ou influenciar a resposta do usuário.

# %% [markdown]
# 1,2 e 3 podem gerar viés vide que dão informações sobre a perguntas. "concorda que é bom", "também acha que ... são os melhores" e "gosta" são trechos que levam consigo expressões de qualidade sobre algo que pode ser o inverso do que quem é questionado acha.

# %% [markdown]
# b) Explique por que essas perguntas podem ser problemáticas para a coleta de dados confiáveis.

# %% [markdown]
# Ao invesar a pesquisa prejudica a confiabilidade da pesquisa e descredibiliza o processo gerando problemas de confiança para o método de pesquisa com o questionário.

# %% [markdown]
# c) Reescreva essas perguntas de forma mais neutra e adequada para uma pesquisa.

# %% [markdown]
# “Como você avalia o nosso atendimento?”
#
# “Nossos preços são como avaliados comparando com a nossa concorrência?”
#
# “Qual a sua avaliação sobre comprar em nossa loja?”

# %% [markdown]
# 4) Classifique cada uma das variáveis abaixo como nominal, ordinal, discreta ou contínua:
#
# a) Número de funcionários de uma empresa
#
#   Discreta
#
# b) Grau de satisfação do cliente (péssimo, ruim, regular, bom, excelente)
#
#   Ordinal
#
# c) Estado civil
#
#   Nominal
#
# d) Escolaridade
#
#   Nominal
#
# e) Altura de um indivíduo
#
#   Contínua
#
# f) Temperatura do ar
#
#   Contínua
#
# g) Quantidade de produtos demandados
#
#   Discreta
#
# h) Faturamento mensal (R$)
#
#   Contínua
#
# i) Avaliação de aplicativo em loja virtual (1 a 5
# estrelas)
#
#   Ordinal
#
# j) Visualizações de um vídeo na internet
#
#   Discreta
#
# k) Tempo de duração de um vídeo na internet
#
#   Contínua
#
# l) Renda familiar em salários mínimos
#
#   Contínua
#
# m) RG e CPF
#
#   Discreta

# %% [markdown]
# 5) Colete informações de 5 colegas da turma contendo pelo menos as seguintes variáveis: - Uma variável nominal - Uma variável ordinal - Uma variável discreta - Uma variável contínua Exemplo de variáveis que poderiam ser utilizadas (para quem estiver sem criatividade): - Gênero, nível de satisfação com o curso, número de disciplinas cursadas no semestre, altura.
#
# a) Organize as informações em um data frame no R ou Python.
#
# b) Apresente o código utilizado.
#
# c) Mostre a saída gerada pelo R ou Python.

# %%
#Gênero, nível de satisfação com o curso, número de disciplinas cursadas no semestre, altura

genero = c("Masculino","Feminino", "Masculino","", "")
satisfacao = c("5","5", "5","5", "4.5")
num_disc = c(5,6, 6, 6, 6)
altura = c(172, 160, 181, 190, 170)

data = data.frame(
    genero = c("Masculino","Feminino", "Masculino","Masculino", "Masculino"),
    satisfacao = c("5","5", "5","5", "4.5"),
    num_disc = c(5,6, 6, 6, 6),
    altura = c(172, 160, 181, 190, 170))

data
summary(data)
# Out:
#   genero    satisfacao num_disc altura
# 1 Masculino 5          5        172
# 2 Feminino  5          6        160
# 3 Masculino 5          6        181
# 4 Masculino 5          6        190
# 5 Masculino 4.5        6        170
#     genero           satisfacao           num_disc       altura
#  Length:5           Length:5           Min.   :5.0   Min.   :160.0
#  Class :character   Class :character   1st Qu.:6.0   1st Qu.:170.0
#  Mode  :character   Mode  :character   Median :6.0   Median :172.0
#                                        Mean   :5.8   Mean   :174.6
#                                        3rd Qu.:6.0   3rd Qu.:181.0
#                                        Max.   :6.0   Max.   :190.0
