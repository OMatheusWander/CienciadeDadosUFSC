# %% [markdown]
# # EGC5310 — Semana 02 — Notebook Estudante
#
# ## Representação de dados e caracterização de problemas computacionais
#
# **Semana:** S02 — 20 e 21 de agosto de 2026
# **Cenário:** Sistema Acadêmico
#
# Pergunta da semana:
#
# > **Como devemos representar os dados de um problema para realizar adequadamente as operações de que precisamos?**
#
# Você não precisa conhecer previamente todas as estruturas apresentadas em aula. Use os exemplos como repertório e concentre-se em **comparar escolhas e justificar decisões**.

# %% [markdown]
# ## Referência rápida — exemplos do álbum de figurinhas
#
# ```python
# # Lista
# figurinha = [37, "Goleiro", "Brasil", False]
#
# # Tupla
# figurinha = (37, "Goleiro", "Brasil", False)
#
# # Dicionário
# figurinha = {
#     "numero": 37,
#     "jogador": "Goleiro",
#     "selecao": "Brasil",
#     "repetida": False
# }
#
# # Conjunto
# tenho = {1, 2, 5, 8, 13}
#
# # Array
# import numpy as np
# quantidades = np.array([1, 0, 2, 1, 3])
#
# # Objeto/classe
# class Figurinha:
#     def __init__(self, numero, jogador, selecao):
#         self.numero = numero
#         self.jogador = jogador
#         self.selecao = selecao
# ```
#
#
# Esses exemplos servem apenas como **repertório**. Você não precisa usar todas as estruturas.

# %% [markdown]
# # Atividade 1 — Duas representações para o mesmo estudante
#
# Um estudante possui:
#
# - matrícula: `1082`
# - nome: `Carla`
# - curso: `Engenharia`
# - semestre de ingresso: `2026.1`
# - situação acadêmica: `ativo`
#
# ## Parte A — Escolha
#
# Escolha **duas formas diferentes** de representar o mesmo estudante. Você pode adaptar os exemplos do álbum ou usar outra representação que conheça.

# %% [markdown]
# ### Representação 1

# %%
estudante_1 = {"nome":"Carla","curso":"Engenharia","semestre_ingresso":"2026.1","situacao_academica":"ativo"}

estudante_1
# Out:
# {'nome': 'Carla',
#  'curso': 'Engenharia',
#  'semestre_ingresso': '2026.1',
#  'situacao_academica': 'ativo'}

# %% [markdown]
# ### Representação 2

# %%
class estudante_2:
  def __init__(self, nome , curso, semestre_ingresso, situacao_academica):
    self.nome = nome
    self.curso = curso
    self.semestre_ingresso = semestre_ingresso
    self.situacao_academica = situacao_academica

carla = [estudante_2("Carla","Engenharia","2026.1","ativo")]
print(f"{estudante_2.curso}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2312/3107120672.py in <cell line: 0>()
#       7
#       8 carla = [estudante_2("Carla","Engenharia","2026.1","ativo")]
# ----> 9 print(f"{estudante_2.curso}")
#
# AttributeError: type object 'estudante_2' has no attribute 'curso'

# %% [markdown]
# ## Parte B — Acesse o curso
#
# Em cada representação, escreva código para obter o curso do estudante.

# %%
# TODO: obtenha o curso usando a representação 1.

curso_1 = estudante_1["curso"]
curso_1
# Out:
# 'Engenharia'

# %%
# TODO: obtenha o curso usando a representação 2.

curso_2 = estudante_2.curso
curso_2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2312/3892229719.py in <cell line: 0>()
#       1 # TODO: obtenha o curso usando a representação 2.
#       2
# ----> 3 curso_2 = estudante_2.curso
#       4 curso_2
#
# AttributeError: type object 'estudante_2' has no attribute 'curso'

# %% [markdown]
# ## Parte C — Compare
#
# Responda com suas palavras.
#
# 1. O significado dos campos fica explícito nas duas representações?
#
# **Resposta:**
#
# ---
#
# 2. Como você acrescentaria uma nova informação, por exemplo `email`?
#
# **Resposta:**
#
# ---
#
# 3. Qual vantagem você percebe na Representação 1?
#
# **Resposta:**
#
# ---
#
# 4. Qual limitação percebe na Representação 1?
#
# **Resposta:**
#
# ---
#
# 5. Qual vantagem você percebe na Representação 2?
#
# **Resposta:**
#
# ---
#
# 6. Qual limitação percebe na Representação 2?
#
# **Resposta:**
#
# ---

# %% [markdown]
# ## Parte D — Decida
#
# > **Qual das duas representações você escolheria neste momento? Por quê?**
#
# Tente justificar mencionando alguma característica dos dados ou da forma como pretende utilizá-los.
#
# **Resposta:**
#
# ---

# %% [markdown]
# # O problema cresceu
#
# Agora o Sistema Acadêmico também precisa representar disciplinas cursadas.
#
# Para cada vínculo entre estudante e disciplina, podemos precisar de:
#
# - código da disciplina;
# - nome;
# - semestre;
# - nota;
# - situação.
#
# Pense:
#
# > **O que pertence ao estudante? O que pertence à disciplina? O que pertence à relação entre estudante e disciplina?**
#
# Descreva uma possibilidade de organização desses dados.
#
# **Sua proposta:**
#
# ---

# %% [markdown]
# # Atividade 2 — Representação e trabalho esperado
#
# Agora compare diferentes maneiras de realizar operações.

# %%
estudantes_lista = [
    {"matricula": 1023, "nome": "Ana", "curso": "CD"},
    {"matricula": 1047, "nome": "Bruno", "curso": "CD"},
    {"matricula": 1082, "nome": "Carla", "curso": "Engenharia"},
    {"matricula": 1125, "nome": "Daniel", "curso": "CD"},
]

estudantes_lista

# %%
estudantes_dict = {
    1023: {"nome": "Ana", "curso": "CD"},
    1047: {"nome": "Bruno", "curso": "CD"},
    1082: {"nome": "Carla", "curso": "Engenharia"},
    1125: {"nome": "Daniel", "curso": "CD"},
}

estudantes_dict

# %% [markdown]
# ## Parte A — Previsão
#
# **Não execute as buscas ainda.**
#
# ### Situação 1 — localizar a matrícula `1082`
#
# Qual representação parece exigir menos trabalho?
#
# **Previsão:**
#
# ---
#
# **Por quê?**
#
# ---
#
# ### Situação 2 — listar todos os estudantes do curso `CD`
#
# Qual representação parece exigir menos trabalho?
#
# **Previsão:**
#
# ---
#
# **Por quê?**
#
# ---

# %% [markdown]
# ## Parte B — Torne o trabalho visível na lista
#
# Complete a função para contar quantas comparações são realizadas.

# %%
def buscar_matricula_contando(estudantes, matricula):
    comparacoes = 0

    for estudante in estudantes:
        # TODO: incremente o número de comparações.

        # TODO: verifique se a matrícula é a procurada.
        # Se for, retorne o estudante e o número de comparações.
        pass

    return None, comparacoes

# %%
# TODO: depois de completar a função, execute os testes.

alvos = [1023, 1082, 1125, 9999]

for alvo in alvos:
    # resultado, comparacoes = buscar_matricula_contando(estudantes_lista, alvo)
    # print(alvo, resultado, comparacoes)
    pass

# %% [markdown]
# ### O que você observou?
#
# A operação era a mesma. O trabalho realizado também foi sempre o mesmo?
#
# **Resposta:**
#
# ---

# %% [markdown]
# ## Parte C — Acesso pelo dicionário

# %%
estudantes_dict.get(1082)

# %% [markdown]
# Compare com a função que percorre a lista.
#
# > **O que desapareceu do código que você escreveu?**
#
# **Resposta:**
#
# ---
#
# > **Isso significa que nenhum trabalho está sendo realizado?**
#
# **Resposta:**
#
# ---

# %% [markdown]
# ## Parte D — Mude a operação
#
# Agora queremos listar todos os estudantes do curso `CD`.
#
# Complete:

# %%
def estudantes_do_curso(estudantes, curso):
    encontrados = []

    for matricula, estudante in estudantes.items():
        # TODO: verifique se o estudante pertence ao curso desejado.
        # TODO: se pertencer, adicione-o à lista encontrados.
        pass

    return encontrados

# %%
# TODO: execute depois de completar a função.

# estudantes_do_curso(estudantes_dict, "CD")

# %% [markdown]
# ### Compare
#
# > **Onde reapareceu o percurso pelos dados?**
#
# **Resposta:**
#
# ---
#
# > **O dicionário era “mais rápido” ou era mais adequado para uma operação específica?**
#
# **Resposta:**
#
# ---

# %% [markdown]
# ## Parte E — Estruturas que você ainda não precisa saber implementar
#
# ### Árvore
#
# ```python
# def buscar(no, alvo):
#     if no is None:
#         return None
#
#     if alvo == no.matricula:
#         return no.estudante
#
#     if alvo < no.matricula:
#         return buscar(no.esquerda, alvo)
#
#     return buscar(no.direita, alvo)
# ```
#
# ### Dados ordenados
#
# ```python
# from bisect import bisect_left
# posicao = bisect_left(matriculas, alvo)
# ```
#
# Você **não precisa saber implementar uma árvore nem explicar `bisect` internamente**.
#
# Descreva o trabalho que parece ocorrer:
#
# - **Lista:**
#   **Resposta:**
#
# - **Dicionário:**
#   **Resposta:**
#
# - **Árvore:**
#   **Resposta:**
#
# - **Dados ordenados:**
#   **Resposta:**

# %% [markdown]
# ## Parte F — Previsão → execução → interpretação
#
# > **Sua previsão inicial mudou?**
#
# **Resposta:**
#
# ---
#
# > **Que característica da representação tornou uma operação mais natural ou aparentemente menos trabalhosa?**
#
# **Resposta:**
#
# ---

# %% [markdown]
# # Caracterizando um problema computacional
#
# Use a ficha construída em aula:
#
# > **PROBLEMA → DADOS → OPERAÇÕES → REPRESENTAÇÃO → TRABALHO ESPERADO → VOLUME → RESTRIÇÕES**
#
# Considere:
#
# > Consultas por **matrícula** são muito frequentes. Também precisamos listar estudantes por **curso** e inserir novos estudantes regularmente.
#
# ## Preencha
#
# ### Problema
# **Resposta:**
#
# ---
#
# ### Dados
# **Resposta:**
#
# ---
#
# ### Operações
# **Resposta:**
#
# ---
#
# ### Representação possível
# **Resposta:**
#
# ---
#
# ### Trabalho esperado
# Pense qualitativamente: olhar um elemento? vários? todos? percorrer? comparar? reorganizar?
#
# **Resposta:**
#
# ---
#
# ### Volume
# Que diferença faria trabalhar com 10, 1.000 ou 10 milhões de estudantes?
#
# **Resposta:**
#
# ---
#
# ### Restrições
# **Resposta:**
#
# ---

# %% [markdown]
# # Atividade 3 — Justifique uma decisão
#
# Escolha uma representação para o requisito anterior.
#
# Sua justificativa deve mencionar:
#
# 1. os **dados**;
# 2. a **operação predominante**;
# 3. alguma **consequência da escolha**.
#
# > Evite respostas como “porque é mais fácil” ou “porque dicionário é melhor”.
#
# ### Minha escolha
#
# **Representação:**
#
# ---
#
# ### Minha justificativa
#
# **Resposta:**
#
# ---

# %% [markdown]
# # Fechamento
#
# ### 1. Existe uma única forma correta de representar os dados?
#
# **Resposta:**
#
# ---
#
# ### 2. Uma representação pode favorecer todas as operações igualmente?
#
# **Resposta:**
#
# ---
#
# ### 3. Complete a frase
#
# > **Uma representação é adequada quando...**
#
# **Resposta:**
#
# ---
#
# ### 4. Pergunta para a próxima semana
#
# Durante esta aula usamos expressões como:
#
# > “parece exigir menos trabalho”.
#
# Mas isso é suficiente?
#
# > **Como poderíamos comparar sistematicamente o trabalho necessário para realizar diferentes operações quando o volume de dados cresce?**
#
# **Minha hipótese:**
#
# ---

# %% [markdown]
# # Para lembrar
#
# > **Melhor para fazer o quê?**
#
# Essa pergunta deve acompanhar suas decisões sobre estruturas de dados ao longo da disciplina.
