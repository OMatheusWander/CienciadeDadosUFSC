# %% [markdown]
# <a href="https://colab.research.google.com/github/OMatheusWander/CienciadeDadosUFSC/blob/Programa%C3%A7%C3%A3o-I/LISTA_06_DE_PROGRAMA%C3%87%C3%83O_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 1

lista = [-72, 12, 2, 7, 16, -18, 20, -24, 26, 0, 32, 15, 38]
lista_final = []
limite_inf = int(input("Digite o limite inferior:"))
limite_sup = int(input("Digite o limite superior:"))

for i in lista:
  if i >= (limite_inf) and i <= limite_sup:
      lista_final.append(i)

print(lista_final)
# Out:
# Digite o limite inferior:2
# Digite o limite superior:20
# [12, 2, 7, 16, 20, 15]

# %%
#Exercício 2

lista = [55, 39, 12, 25, 95, 2]

media_lista = sum(lista) / len(lista)
print(media_lista)
valor = 0
distancia_relativa_media = abs(media_lista - valor )
menor_valor = 999

for valor in lista:
    distancia_relativa_media = abs(media_lista - valor)
    if distancia_relativa_media < menor_valor - media_lista :
      menor_valor = valor

menor_valor
# Out:
# 38.0
# 39

# %%
#Exercício 3

notas = [3.0, 4.0, 5.0, 6.0, 3.0]
novas_notas = []
x = 0

maior_nota = max(notas)
print(f"Maior nota: {maior_nota}")

for i in notas:
  x = (i*10)/maior_nota
  novas_notas.append(x)
  print(f"Nota anterior:{i} -> Nota Ponderada: {x:.2f}")
# Out:
# Maior nota: 6.0
# Nota anterior:3.0 -> Nota Ponderada: 5.00
# Nota anterior:4.0 -> Nota Ponderada: 6.67
# Nota anterior:5.0 -> Nota Ponderada: 8.33
# Nota anterior:6.0 -> Nota Ponderada: 10.00
# Nota anterior:3.0 -> Nota Ponderada: 5.00

# %%
#Exercício 4
import random

lista = []
for índice in range(500):
  lista.append(random.randint(1,5000))


#entrada de dados
inteiro = input("Digite um número inteiro:")
outro_inteiro = input("Digite um outro número inteiro:")
inteiro_encontrado = ""
outro_inteiro_encontrado = ""

#processamento
for item in lista:
    if item == inteiro:
        print(f"Valor {inteiro} encontrado!")
        inteiro_encontrado += "Encontrado"
        break
for item in lista:
    if item == outro_inteiro:
        print(f"Valor {outro_inteiro} encontrado!")
        outro_inteiro_encontrado += "Encontrado"
        break

if inteiro_encontrado == "Encontrado" and outro_inteiro == "Encontrado":
  if inteiro > outro_inteiro:
  print(f"Valor achado primeiro pela esquerda: {achado_primeiro_esquerda}")
  print(f"Valor achado primeiro pela direita: {achado_primeiro_direita}")
elif inteiro in lista and outro_inteiro not in lista:
  print(f"O valor {outro_inteiro} não existe na lista.")
elif inteiro not in lista and outro_inteiro in lista:
  print(f"O valor {inteiro} não existe na lista.")
else: print('Nenhum dos valores existe na lista')
# Out:
# Digite um número inteiro:5
# Digite um outro número inteiro:10
# Nenhum dos valores existe na lista

# %%
import random

# 1. Criando e preenchendo a lista
lista = []
for índice in range(500):
    lista.append(random.randint(1, 5000))

print("Lista gerada:", lista)
print("-" * 50)

# 2. Recebendo os inputs convertidos para inteiro
inteiro_1 = int(input("Digite um número inteiro: "))
inteiro_2 = int(input("Digite outro número inteiro: "))

print("-" * 50)

# 3. Verificando a existência individual de cada um na lista
existe_1 = inteiro_1 in lista
existe_2 = inteiro_2 in lista

# Caso 1: Nenhum dos dois existe
if not existe_1 and not existe_2:
    print("Nenhum dos dois valores existe na lista.")

# Caso 2: O primeiro não existe
elif not existe_1:
    print(f"O valor {inteiro_1} não existe na lista.")

# Caso 3: O segundo não existe
elif not existe_2:
    print(f"O valor {inteiro_2} não existe na lista.")

# Caso 4: Ambos existem (aí sim fazemos a busca por posições)
else:
    primeiro_valor_pela_esquerda = None
    primeiro_valor_pela_direita = None

    # Busca pela ESQUERDA (do início para o fim)
    for número in lista:
        if número == inteiro_1 or número == inteiro_2:
            primeiro_valor_pela_esquerda = número
            break

    # Busca pela DIREITA (do fim para o início)
    for número in reversed(lista):
        if número == inteiro_1 or número == inteiro_2:
            primeiro_valor_pela_direita = número
            break

    print(f"Valor achado primeiro pela esquerda (início): {primeiro_valor_pela_esquerda}")
    print(f"Valor achado primeiro pela direita (fim): {primeiro_valor_pela_direita}")
# Out:
# Lista gerada: [4913, 4702, 1405, 4097, 3643, 2065, 957, 1855, 3769, 4731, 4468, 3216, 1000, 1467, 3434, 1515, 703, 1499, 4980, 4183, 857, 650, 3545, 1757, 4168, 1381, 385, 2778, 747, 2043, 4653, 3510, 3384, 2445, 2565, 136, 3645, 1846, 4886, 1578, 4821, 2570, 1061, 79, 3509, 1582, 3065, 4189, 421, 2086, 2857, 2997, 1719, 2211, 2255, 3402, 322, 3587, 1645, 1731, 1957, 2881, 265, 3321, 1547, 3189, 2883, 4133, 4286, 2664, 2331, 2613, 2097, 601, 3069, 2296, 1849, 4171, 2570, 2637, 3167, 2773, 2125, 1045, 2414, 4327, 1377, 2, 4506, 3551, 206, 4215, 1874, 2609, 2012, 4046, 3380, 3517, 2266, 2955, 4355, 2222, 1931, 1575, 1866, 1042, 818, 4065, 4433, 4086, 216, 645, 1400, 2223, 2500, 4070, 4076, 2496, 1666, 2738, 1865, 4133, 4930, 3740, 793, 3464, 1284, 1778, 341, 1691, 1494, 4797, 3825, 371, 4961, 2632, 2063, 2081, 942, 2272, 1482, 3351, 4270, 4784, 3720, 1955, 291, 1822, 3662, 1150, 4938, 4105, 2062, 3088, 3309, 2731, 433, 275, 268, 1505, 782, 1268, 1160, 2009, 2840, 1542, 1574, 3885, 4803
# ...

# %%
#Exercício 5
import random

posição_2 = 0
posição_1 = 0
# 1. Criando e preenchendo a lista
lista = []
for índice in range(500):
    lista.append(random.randint(1, 5000))

print("Lista gerada:", lista)
print("-" * 50)

# 2. Recebendo os inputs convertidos para inteiro
inteiro_1 = int(input("Digite um número inteiro: "))
inteiro_2 = int(input("Digite outro número inteiro: "))

print("-" * 50)

# 3. Verificando a existência individual de cada um na lista
existe_1 = inteiro_1 in lista
existe_2 = inteiro_2 in lista

# Caso 1: Nenhum dos dois existe
if not existe_1 and not existe_2:
    print("Nenhum dos dois valores existe na lista.")

# Caso 2: O primeiro não existe
elif not existe_1:
    print(f"O valor {inteiro_1} não existe na lista.")

# Caso 3: O segundo não existe
elif not existe_2:
    print(f"O valor {inteiro_2} não existe na lista.")

# Caso 4: Ambos existem (aí sim fazemos a busca por posições)
else:
    primeiro_valor_pela_esquerda = None
    primeiro_valor_pela_direita = None

    # Busca pela ESQUERDA (do início para o fim)
    for número in lista:
      if número == inteiro_1 or número == inteiro_2:
        primeiro_valor_pela_esquerda = número
        break
      posição_1 +=1


    # Busca pela DIREITA (do fim para o início)
    for número in reversed(lista):
      if número == inteiro_1 or número == inteiro_2:
        primeiro_valor_pela_direita = número
        break
      posição_2 +=1


    print(f"Valor achado primeiro pela esquerda (início): {primeiro_valor_pela_esquerda} (indice {posição_1})")
    print(f"Valor achado primeiro pela direita (fim): {primeiro_valor_pela_direita} (indice {posição_2})")
# Out:
# Lista gerada: [422, 3762, 3460, 899, 4632, 2991, 1972, 4773, 3825, 2883, 1055, 3059, 987, 2029, 2628, 2268, 2065, 3513, 338, 2389, 2944, 16, 2190, 4327, 3486, 3907, 1180, 3300, 1584, 1359, 2068, 4309, 1955, 3744, 1262, 2669, 1711, 3415, 2728, 1717, 2279, 1603, 3902, 4988, 4459, 4112, 3525, 1748, 1403, 994, 2994, 1303, 2527, 3410, 2121, 3245, 4874, 4982, 3468, 242, 3263, 1550, 1623, 882, 759, 3368, 2410, 597, 2784, 3135, 4981, 426, 1986, 2512, 300, 697, 2823, 3384, 2531, 2202, 303, 3950, 505, 1132, 910, 3792, 407, 4022, 2094, 3157, 4449, 1909, 1135, 12, 199, 447, 1885, 4598, 3043, 3494, 108, 4372, 1230, 1123, 3254, 3195, 841, 3503, 2160, 658, 4458, 869, 3520, 2350, 3870, 3061, 3898, 4312, 978, 3253, 1380, 3540, 2485, 1042, 2358, 2686, 3559, 1499, 3254, 1504, 1555, 918, 3835, 3177, 3114, 1808, 1019, 1688, 2391, 3561, 4281, 2022, 2124, 2169, 399, 4676, 3461, 2705, 3635, 2741, 1273, 450, 4456, 4900, 3425, 3221, 976, 579, 984, 4108, 1084, 1896, 3116, 2327, 3960, 4815, 4384, 4450, 4213, 37
# ...

# %%
#Exercício 6

lista = [4, 7, 10, 3, 8, 11, 2]
lista_pares = []
lista_impares = []

print(f'Lista original: {lista}')

for valor in lista:
  if valor % 2 == 0:
    lista_pares.append(valor)
  else:
    lista_impares.append(valor)

print(f'Lista de pares: {lista_pares}')
print(f'Lista de impares: {lista_impares}')
print(f'Quantidade de pares: {len(lista_pares)}')
print(f'Quantidade de impares: {len(lista_impares)}')
# Out:
# Lista original: [4, 7, 10, 3, 8, 11, 2]
# Lista de pares: [4, 10, 8, 2]
# Lista de impares: [7, 3, 11]
# Quantidade de pares: 4
# Quantidade de impares: 3

# %%
#Exercício 7

lista = [5, 100, 2, 5, -57, 8, 2, 9, 100, 8, 1, 23, -12, -12, 0, 100, 0, 333, 49]
lista_valores_unicos = []
print(f"Lista original: {lista}")

for valor in lista:
  if valor not in lista_valores_unicos:
    lista_valores_unicos.append(valor)

print(f"Lista sem repetição: {lista_valores_unicos}")
# Out:
# Lista original: [5, 100, 2, 5, -57, 8, 2, 9, 100, 8, 1, 23, -12, -12, 0, 100, 0, 333, 49]
# Lista sem repetição: [5, 100, 2, -57, 8, 9, 1, 23, -12, 0, 333, 49]

# %%
#Exercício 8

lista = [10, 20, 30, 40]
lista_nova = lista
valor_inserir = int(input("Digite o valor a inserir na lista:"))

indice = int(input("Digite o índice de inserção:"))

print(f"Lista original: {lista}")
posicao=0

for valor in range(len(lista)):
 if valor == indice:
  lista.insert(indice, valor_inserir)

if valor_inserir in lista_nova:
  print(f"Lista após inserção: {lista_nova}")
else: print("Índice inválido")
# Out:
# Digite o valor a inserir na lista:50
# Digite o índice de inserção:8
# Lista original: [10, 20, 30, 40]
# Índice inválido

# %%
#Exercício 9
import random

lista = []
for índice in range(10):
  lista.append(random.randint(1,100))

lista_copia = lista[:]

print(f"Lista original gerada aleatoriamente: {lista}")


índice = int(input("Digite o índice (0 a 9) que deseja alterar:"))

if índice < 0 or índice > 9:
  print("Índice inválido")

else:
  novo_valor = int(input("Digite o novo valor:"))
  lista[índice] = novo_valor

  print(f"Lista original alterada: {lista}")
  print(f"Cópia da lista original: {lista_copia}")

  if lista == lista_copia:
    print("As listas são iguais.")
  else: print("As listas são diferentes.")
# Out:
# Lista original gerada aleatoriamente: [44, 54, 99, 58, 51, 52, 100, 76, 65, 46]
# Digite o índice (0 a 9) que deseja alterar:2
# Digite o novo valor:53
# Lista original alterada: [44, 54, 53, 58, 51, 52, 100, 76, 65, 46]
# Cópia da lista original: [44, 54, 99, 58, 51, 52, 100, 76, 65, 46]
# As listas são diferentes.

# %%
#Exercício 10

import random

lista = []
for índice in range(20):
  lista.append(random.randint(1,100))

print(f"Lista gerada: {lista}")


primeiro_valor_sequencia = int(input("Digite o primeiro valor da sequência:"))
segundo_valor_sequencia = int(input("Digite o segundo valor da sequência:"))

sequencia_existe = False
índice_inicial_seq = -1


if primeiro_valor_sequencia in  lista:
  for índice in range(len(lista)):
      if lista.index(primeiro_valor_sequencia) == -1:
        break

      if índice < len(lista)-1:
        if lista[índice+1] == segundo_valor_sequencia:
          sequencia_existe == True
          índice_inicial_seq = índice
          break

if sequencia_existe: print(f"Sequência encontrada a partir da sequência")
else:print("A sequencia não existe")
# Out:
# Lista gerada: [5, 88, 38, 75, 18, 31, 38, 20, 26, 45, 4, 39, 53, 92, 3, 5, 70, 45, 22, 41]
# Digite o primeiro valor da sequência:18
# Digite o segundo valor da sequência:38
# A sequencia não existe
